# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("hr_analytics.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %%
left = df[df.left==1]
left.shape
# Out:
# (3571, 10)

# %%
department = pd.get_dummies(df["Department"])
department.head()
# Out:
#       IT  RandD  accounting     hr  management  marketing  product_mng  sales  \
# 0  False  False       False  False       False      False        False   True
# 1  False  False       False  False       False      False        False   True
# 2  False  False       False  False       False      False        False   True
# 3  False  False       False  False       False      False        False   True
# 4  False  False       False  False       False      False        False   True
#
#    support  technical
# 0    False      False
# 1    False      False
# 2    False      False
# 3    False      False
# 4    False      False

# %%
salary = pd.get_dummies(df["salary"])
salary.head()
# Out:
#     high    low  medium
# 0  False   True   False
# 1  False  False    True
# 2  False  False    True
# 3  False   True   False
# 4  False   True   False

# %%
result = pd.concat([df, department, salary], axis = 1)
result.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary  ...     hr  management  marketing  product_mng  sales  support  \
# 0     low  ...  False       False      False        False   True    False
# 1  medium  ...  False       False      False        False   True    False
# 2  medium  ...  False       False      False        False   True    False
# 3     low  ...  False       False      False        False   True    False
# 4     low  ...  False       False      False        False   True    False
#
#    technical   high    low  medium
# 0      False  False   True   False
# 1      False  False  False    True
# 2      False  False  False    True
# 3      False  False   True   False
# 4      False  False   True   False
#
# [5 rows x 23 columns]

# %%
result = result.drop(["Department", "salary"], axis = 1)
result.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years     IT  \
# 0                   3              0     1                      0  False
# 1                   6              0     1                      0  False
# 2                   4              0     1                      0  False
# 3                   5              0     1                      0  False
# 4                   3              0     1                      0  False
#
#    RandD  ...     hr  management  marketing  product_mng  sales  support  \
# 0  False  ...  False       False      False        False   True    False
# 1  False  ...  False       False      False        False   True    False
# 2  False  ...  False       False      False        False   True    False
# 3  False  ...  False       False      False        False   True    False
# 4  False  ...  False       False      False        False   True    False
#
#    technical   high    low  medium
# 0      False  False   True   False
# 1      False  False  False    True
# 2      False  False  False    True
# 3      False  False   True   False
# 4      False  False   True   False
#
# [5 rows x 21 columns]

# %%
X = result.drop(["left"], axis = 1)
X.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  promotion_last_5years     IT  RandD  \
# 0                   3              0                      0  False  False
# 1                   6              0                      0  False  False
# 2                   4              0                      0  False  False
# 3                   5              0                      0  False  False
# 4                   3              0                      0  False  False
#
#    accounting     hr  management  marketing  product_mng  sales  support  \
# 0       False  False       False      False        False   True    False
# 1       False  False       False      False        False   True    False
# 2       False  False       False      False        False   True    False
# 3       False  False       False      False        False   True    False
# 4       False  False       False      False        False   True    False
#
#    technical   high    low  medium
# 0      False  False   True   False
# 1      False  False  False    True
# 2      False  False  False    True
# 3      False  False   True   False
# 4      False  False   True   False

# %%
y = result["left"]
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: left, dtype: int64

# %%
X_test, X_train, y_test, y_train = train_test_split(X, y, test_size = 0.2)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %%
model.score(X_test, y_test)
# Out:
# 0.7972331027585632
